# %% [markdown]
# # BoxPlot

# %%
import seaborn as sns

titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import matplotlib.pyplot as plt

sns.boxplot(x = titanic["age"])
plt.show()

# %%
sns.boxplot(x = "who", y = "fare", hue = "alive", data = titanic)
plt.show()

# %%
sns.boxplot(x = "alive", y = "fare", hue = "who", data = titanic)
plt.show()

# %%
# linewidth

sns.boxplot(x="who", y="fare", hue="embark_town",data=titanic,linewidth=3)
plt.show()

# %%
sns.boxplot(x="fare", y="who", hue="embark_town",data=titanic,orient="h")
plt.show()

# %%
# Source of this lecture - 
# https://www.tutorialspoint.com/seaborn/seaborn_boxplot_method.htm#:~:text=The%20seaborn.,levels%20of%20a%20categorical%20variable.

# %% [markdown]
# # Tableau
