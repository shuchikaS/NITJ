# %%
# WAP to multiply two 1D arrays

print("*** Program to input two 1D matrices A and B, then print B' and calculate AB' ***")

cols1 = int(input("Enter no. of cols of matrix a: "))

cols2 = int(input("Enter no. of cols of matrix b: "))

if cols1 != cols2:
    sys.exit("Incorrect dimensions of the two arrays!!! Cols of A should match cols of B to calculate AB' correctly!")

 # Input first Array
print("Enter values of Matrix A:")
mat1 = []
for i in range(cols1):
    mat1.append(int(input()))
print("Matrix A: ", mat1)

# Input second array
print("Enter values of Matrix B:")
mat2 = []
for j in range(cols2):
    mat2.append(int(input()))
print("Matrix B: ", mat2)


# Compute Dot product

mat4 = [0]
    
for i in range(cols1):
    mat4[0] += mat1[i]*mat2[i]
print("Result of Matrix Multiplication of A and B' : ", mat4)
# Out:
# *** Program to input 2 1D matrices A and B, then print B' and calculate AB' ***
# Enter no. of cols of matrix a: 3
# Enter no. of cols of matrix b: 3
# Enter values of Matrix A:
# 1
# 2
# 3
# Matrix A:  [1, 2, 3]
# Enter values of Matrix B:
# 4
# 5
# 6
# Matrix B:  [4, 5, 6]
# Result of Matrix Multiplication of A and B' :  [32]

# %%
# Program 2 - WAP to multiply two arrays

import sys
print("*** Program to input 2 matrices A and B, then print B' and calculate AB' ***")

rows1 = int(input("Enter no. of rows of matrix a: "))
cols1 = int(input("Enter no. of cols of matrix a: "))

rows2 = int(input("Enter no. of rows of matrix b: "))
cols2 = int(input("Enter no. of cols of matrix b: "))

if cols1 != cols2:
    sys.exit("Incorrect dimensions of the two arrays!!! Cols of A should match cols of B to calculate AB' correctly!")

 # Input first Array
print("Enter values of Matrix A row-wise:")
mat1 = []
for i in range(rows1):
    a = []
    for j in range(cols1):
        a.append(int(input()))
    mat1.append(a)
print("Matrix A: ", mat1)

# Input second array
print("Enter values of Matrix B row-wise:")
mat2 = []
for i in range(rows2):
    a = []
    for j in range(cols2):
        a.append(int(input()))
    mat2.append(a)
print("Matrix B: ", mat2)

# Calculate Transpose
rows3 = cols2
cols3 = rows2

mat3 = []
for i in range(rows3):
    a = []
    for j in range(cols3):
        a.append(0)
    mat3.append(a)

for i in range(rows3):
    for j in range(cols3):
        mat3[i][j] = mat2[j][i]
        
print("Transpose of Matrix B: ", mat3)

# Compute Dot product

mat4 = []
for i in range(rows1):
    a = []
    for j in range(cols3):
        a.append(0)
    mat4.append(a)

    
for i in range(rows1):
    for j in range(cols3):
        mat4[i][j] = 0
        for k in range(cols1):
            mat4[i][j] += mat1[i][k] * mat3[k][j]
print("Result of Matrix Multiplication of A and B' : ", mat4)
# Out:
# *** Program to input 2 matrices A and B, then print B' and calculate AB' ***
# Enter no. of rows of matrix a: 2
# Enter no. of cols of matrix a: 3
# Enter no. of rows of matrix b: 2
# Enter no. of cols of matrix b: 3
# Enter values of Matrix A row-wise:
# 1
# 2
# 3
# 4
# 5
# 6
# Matrix A:  [[1, 2, 3], [4, 5, 6]]
# Enter values of Matrix B row-wise:
# 7
# 8
# 9
# 10
# 11
# 12
# Matrix B:  [[7, 8, 9], [10, 11, 12]]
# Transpose of Matrix B:  [[7, 10], [8, 11], [9, 12]]
# Result of Matrix Multiplication of A and B' :  [[50, 68], [122, 167]]
